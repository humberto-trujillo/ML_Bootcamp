# %% [markdown]
# # Linear Regression Tensorflow

# %%
import tensorflow.keras
from tensorflow.keras import models, layers, optimizers
import numpy as np

# %%
# Create some fake data
x = np.linspace(1, 2, 200)
y = (x * 8) + (np.random.randn(x.shape[0]) * 0.5)

# %%
# Plot the data
import matplotlib.pyplot as plt
plt.plot(x, y, 'k.')
plt.show()

# %%
# Build model
model = models.Sequential()
model.add(layers.Dense(1, input_dim=1, activation='linear'))

# %%
# Get initial, untrained weights
print(model.layers[0].get_weights())
# Out:
# [array([[-0.47277308]], dtype=float32), array([0.], dtype=float32)]

# %%
# Configure training process
model.compile(optimizer=optimizers.SGD(), loss='mse', metrics=['mse'])

# %%
# Train model
model.fit(x, y, batch_size=1, epochs=50, shuffle=False)
# Out:
# Train on 200 samples
# Epoch 1/50
# 200/200 [==============================] - 0s 2ms/sample - loss: 5.2591 - mse: 5.2591
# Epoch 2/50
# 200/200 [==============================] - 0s 868us/sample - loss: 0.5981 - mse: 0.5981
# Epoch 3/50
# 200/200 [==============================] - 0s 867us/sample - loss: 0.5723 - mse: 0.5723
# Epoch 4/50
# 200/200 [==============================] - 0s 1ms/sample - loss: 0.5486 - mse: 0.5486
# Epoch 5/50
# 200/200 [==============================] - 0s 906us/sample - loss: 0.5268 - mse: 0.5268
# Epoch 6/50
# 200/200 [==============================] - 0s 1ms/sample - loss: 0.5066 - mse: 0.5066
# Epoch 7/50
# 200/200 [==============================] - 0s 911us/sample - loss: 0.4881 - mse: 0.4881
# Epoch 8/50
# 200/200 [==============================] - 0s 949us/sample - loss: 0.4710 - mse: 0.4710
# Epoch 9/50
# 200/200 [==============================] - 0s 978us/sample - loss: 0.4552 - mse: 0.4552
# Epoch 10/50
# 200/200 [==============================] - 0s 956us/sample - loss: 0.4407 - mse: 0.4407
# Epoch 11/50
# 200/200 [==============================] - 0s 1ms/sample - loss: 0.4274 - mse: 0.4274
# Epoch 12/50
# 200/200 [==============================] - 0s 923us/sample - loss: 0.4150 - mse: 0.4150
# Epoch 13/50
# 200/200 [==============================] - 0s 840us/sample - loss: 0.4037 - mse: 0.4037
# Epoch 14/50
# 200/200 [==============================] - 0s 1ms/sample - loss: 0.3932 - mse: 0.3932
# Epoch 15/50
# 200/200 [==============================] - 0s 981us/sample - loss: 0.3835 - mse: 0.3835
# Epoch 16/50
# 200/200 [==============================] - 0s 833us/sample - loss: 0.3746 - mse: 0.3746
# Epoch 17/50
# 200/200 [==============================] - 0s 796us/sample - loss: 0.3664 - mse: 0.3664
# Epoch 18/50
# 200/200 [==============================] - 0s 812us/sample - loss: 0.3588 - mse: 0.3588
# Epoch 19/50
# 200/200 [==============================] - 0s 919us/sample - loss: 0.3518 - mse: 0.3518
# Epoch 20/50
# 200/200 [==============================] - 0s 928us/sample - loss: 0.3453 - mse: 0.3453
# Epoch 21/50
# 200/200 [==============================] - 0s 835us/sample - loss: 0.3394 - mse: 0.3394
# Epoch 22/50
# 200/200 [==============================] - 0s 857us/sample - loss: 0.3339 - mse: 0.3339
# Epoch 23/50
# 200/200 [==============================] - 0s 858us/sample - loss: 0.3288 - mse: 0.3288
# Epoch 24/50
# 200/200 [==============================] - 0s 885us/sample - loss: 0.3241 - mse: 0.3241
# Epoch 25/50
# 200/200 [==============================] - 0s 869us/sample - loss: 0.3198 - mse: 0.3198
# Epoch 26/50
# 200/200 [==============================] - 0s 896us/sample - loss: 0.3158 - mse: 0.3158
# Epoch 27/50
# 200/200 [==============================] - 0s 912us/sample - loss: 0.3121 - mse: 0.3121
# Epoch 28/50
# 200/200 [==============================] - 0s 881us/sample - loss: 0.3087 - mse: 0.3087
# Epoch 29/50
# 200/200 [==============================] - 0s 1ms/sample - loss: 0.3055 - mse: 0.3055
# Epoch 30/50
# 200/200 [==============================] - 0s 848us/sample - loss: 0.3026 - mse: 0.3026
# Epoch 31/50
# 200/200 [==============================] - 0s 878us/sample - loss: 0.2999 - mse: 0.2999
# Epoch 32/50
# 200/200 [==============================] - 0s 881us/sample - loss: 0.2974 - mse: 0.2974
# Epoch 33/50
# 200/200 [==============================] - 0s 1ms/sample - loss: 0.2951 - mse: 0.2951
# Epoch 34/50
# 200/200 [==============================] - 0s 890us/sample - loss: 0.2930 - mse: 0.2930
# Epoch 35/50
# 200/200 [==============================] - 0s 940us/sample - loss: 0.2910 - mse: 0.2910
# Epoch 36/50
# 200/200 [==============================] - 0s 906us/sample - loss: 0.2892 - mse: 0.2892
# Epoch 37/50
# 200/200 [==============================] - 0s 915us/sample - loss: 0.2875 - mse: 0.2875
# Epoch 38/50
# 200/200 [==============================] - 0s 919us/sample - loss: 0.2859 - mse: 0.2859
# Epoch 39/50
# 200/200 [==============================] - 0s 877us/sample - loss: 0.2845 - mse: 0.2845
# Epoch 40/50
# 200/200 [==============================] - 0s 769us/sample - loss: 0.2831 - mse: 0.2831
# Epoch 41/50
# 200/200 [==============================] - 0s 810us/sample - loss: 0.2819 - mse: 0.2819
# Epoch 42/50
# 200/200 [==============================] - 0s 878us/sample - loss: 0.2807 - mse: 0.2807
# Epoch 43/50
# 200/200 [==============================] - 0s 892us/sample - loss: 0.2797 - mse: 0.2797
# Epoch 44/50
# 200/200 [==============================] - 0s 884us/sample - loss: 0.2787 - mse: 0.2787
# Epoch 45/50
# 200/200 [==============================] - 0s 896us/sample - loss: 0.2778 - mse: 0.2778
# Epoch 46/50
# 200/200 [==============================] - 0s 845us/sample - loss: 0.2769 - mse: 0.2769
# Epoch 47/50
# 200/200 [==============================] - 0s 901us/sample - loss: 0.2761 - mse: 0.2761
# Epoch 48/50
# 200/200 [==============================] - 0s 1ms/sample - loss: 0.2754 - mse: 0.2754
# Epoch 49/50
# 200/200 [==============================] - 0s 880us/sample - loss: 0.2747 - mse: 0.2747
# Epoch 50/50
# 200/200 [==============================] - 0s 947us/sample - loss: 0.2740 - mse: 0.2740

# %%
# Try predicting 1 value
model.predict([1.1])
# Out:
# array([[9.053711]], dtype=float32)

# %%
# Plot fitted line versus actual data
y_pred = model.predict(x)
plt.plot(x, y, 'k.', x, y_pred, 'b')
plt.show()

# %%
# Get trained weights
print(model.layers[0].get_weights())
# Out:
# [array([[7.532049]], dtype=float32), array([0.7684568], dtype=float32)]
